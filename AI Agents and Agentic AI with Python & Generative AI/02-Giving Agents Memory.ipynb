# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %pip install litellm 
from litellm import completion # serves as the bridge between your code and the LLM, allowing you to send prompts and receive responses in a structured and efficient way
from typing import List, Dict

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content

# %%
# without context/memory
messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)

# Second query without including the previous response
messages = [
    {"role": "user", "content": "Update the function to include documentation."}
]

print("--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--")

response = generate_response(messages)
print(response)
# Out:
# Certainly! In functional programming, we aim to write code that minimizes side effects and leverages immutable data structures. Here's a Python function that swaps the keys and values of a dictionary using a more functional approach by utilizing dictionary comprehensions:
#
# ```python
# def swap_keys_and_values(input_dict):
#     if len(set(input_dict.values())) != len(input_dict.values()):
#         raise ValueError("Duplicate values detected, which are not allowed because they will become keys.")
#
#     return {value: key for key, value in input_dict.items()}
#
# # Example usage:
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_keys_and_values(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Explanation:
# - The function `swap_keys_and_values` takes a dictionary `input_dict` as its argument.
# - It first checks if there are any duplicate values in the dictionary using a `set`, raising an error if duplicates exist. This check ensures that swapping keys and values does not lead to any key collisions, as keys in a dictionary must be unique.
# - It then returns a new dictionary by using a dictionary comprehension, where each key-value pair `(key, value)` in the input dictionary is swapped to `(value, key)` in the resulting dictionary.
#
# This method maintains immutability by avoiding in-place modifications of the input dictionary and instead creates a new dictionary with the swapped key-value pairs.
# --++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--
# Certainly! Providing proper documentation for a function is a great practice as it helps others understand how to use it effectively. Here's an example of how you might update a function to include documentation using Python's docstring format.
#
# ```python
# def add_numbers(a, b):
#     """
#     Adds two numbers together.
#
#     Parameters:
#     a (int or float): The first number to be added.
#     b (int or float): The second number to be added.
#
#     Returns:
#     int or float: The sum of the two input numbers.
#
#     Example:
#     >>> add_numbers(2, 3)
#     5
#     >>> add_numbers(4.5, 2.3)
#     6.8
#     """
#     return a + b
# ```
#
# ### Explanation
#
# - **Docstring**: A docstring is a string literal specified in source code that is used to document a specific segment of code.
# - **Triple Quotes**: The use of triple quotes allows the string to span multiple lines, making it ideal for this kind of detailed documentation.
# - **Parameters**: It includes a section where you describe each parameter, including its name, type, and purpose.
# - **Returns**: This section describes what the function returns, including the type and meaning of the returned value.
# - **Example**: Providing an example can further clarify how the function is intended to be used and what its output should look like.
#
# Adding this kind of documentation will make the function more understandable and maintainable, especially as part of a larger codebase.

# %%
# with context/memory - Explanation: By including the assistant’s previous response in the messages, the model can maintain context and provide an appropriate response to the follow-up question.
messages = [
   {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
   {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)

print("--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--")

# We are going to make this verbose so it is clear what
# is going on. In a real application, you would likely
# just append to the messages list.
messages = [
   {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
   {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."},
   
   # Here is the assistant's response from the previous step
   # with the code. This gives it "memory" of the previous
   # interaction.
   {"role": "assistant", "content": response},
   
   # Now, we can ask the assistant to update the function
   {"role": "user", "content": "Update the function to include documentation."}
]

response = generate_response(messages)
print(response)
# Out:
# Certainly! In functional programming, we often use immutable structures and focus on expressions rather than statements. Here's how you can write a function to swap the keys and values in a dictionary using Python, leveraging functional programming concepts:
#
# ```python
# def swap_keys_values(d):
#     return {value: key for key, value in d.items()}
#
# # Example usage
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_keys_values(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Explanation:
# - **Immutable Structures**: The function returns a new dictionary with swapped keys and values instead of modifying the original dictionary in place.
# - **Dictionary Comprehension**: We use a dictionary comprehension to create a new dictionary. It iterates over each key-value pair in the original dictionary and constructs a new pair with the value as the key and the key as the value.
# - **Functional Nature**: The function is a pure function; it doesn't have side effects and returns the same output for the same input.
#
# Remember that this approach assumes that the values in the original dictionary are hashable and unique, as dictionary keys must be unique and hashable. If there are duplicate values in the original dictionary, some keys will be overwritten in the swapped dictionary.
# --++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--++--
# Certainly! Adding documentation to a function is a good practice as it helps others (and your future self) understand the purpose and usage of the function. Here is the updated function with a docstring:
#
# ```python
# def swap_keys_values(d):
#     """
#     Swap the keys and values in a dictionary.
#
#     This function takes a dictionary `d` and returns a new dictionary where
#     the original keys are values and the original values are keys.
#
#     Parameters:
#     d (dict): The dictionary to have its keys and values swapped.
#
#     Returns:
#     dict: A new dictionary with keys and values swapped.
#
#     Note:
#     - The values in the input dictionary must be hashable and unique.
#     - If there are duplicate values in the original dictionary, the last key-value pair encountered
#       will be used in the resulting dictionary.
#
#     Example:
#     >>> original_dict = {'a': 1, 'b': 2, 'c': 3}
#     >>> swap_keys_values(original_dict)
#     {1: 'a', 2: 'b', 3: 'c'}
#     """
#     return {value: key for key, value in d.items()}
#
# # Example usage
# if __name__ == "__main__":
#     original_dict = {'a': 1, 'b': 2, 'c': 3}
#     swapped_dict = swap_keys_values(original_dict)
#     print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Explanation of the Docstring:
# - **Purpose**: It clearly states that the function swaps keys and values in a dictionary.
# - **Parameters**: Describes the expected input to the function.
# - **Returns**: Describes the output of the function.
# - **Note**: Highlights important considerations regarding input data constraints and behavior.
# - **Example**: Provides an example illustrating how to use the function, which clarifies its behavior.
